# %% [markdown]
# ## Task 5: Text processing by stemming, lemmatization and removing stop words
# ### Sabeel Khan, CSUID: 2829233, CIS593 - BIG DATA

# %% [markdown]
# ### Importing necessary libraries: nltk, pandas, PorterStemmer and WordNetLemmatizer

# %%
import numpy as np
import pandas as pd 
import string as st
import re
import nltk
from nltk import PorterStemmer, WordNetLemmatizer
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\sabee\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\wordnet.zip.
# True

# %% [markdown]
# ### Reading my 'tweets.csv' file with just the text

# %%
data = pd.read_csv('tweets.csv')
data.head()
# Out:
#                                                 text
# 0  RT @Printer_Gobrrr: #LightningNetwork #Bitcoin...
# 1  RT @Blockworks_: 🚨 Meta has filed trademarks a...
# 2  RT @Steampad: 🔥 Unveiling our most Powerful Ch...
# 3  @kseni_cher Sol Projects are going crazy latel...
# 4  @d3protocol ⚽️ BETERO ⚽️\n\n📲 New platform for...

# %%
data.shape
# Out:
# (7157, 1)

# %% [markdown]
# ### Removing punctuation for cleaner text

# %%
def remove_punct(text):
    return ("".join([ch for ch in text if ch not in st.punctuation]))

# %%
data['removed_punc'] = data['text'].apply(lambda x: remove_punct(x))
data.head()
# Out:
#                                                 text  \
# 0  RT @Printer_Gobrrr: #LightningNetwork #Bitcoin...
# 1  RT @Blockworks_: 🚨 Meta has filed trademarks a...
# 2  RT @Steampad: 🔥 Unveiling our most Powerful Ch...
# 3  @kseni_cher Sol Projects are going crazy latel...
# 4  @d3protocol ⚽️ BETERO ⚽️\n\n📲 New platform for...
#
#                                         removed_punc
# 0  RT PrinterGobrrr LightningNetwork Bitcoin tran...
# 1  RT Blockworks 🚨 Meta has filed trademarks appl...
# 2  RT Steampad 🔥 Unveiling our most Powerful Char...
# 3  ksenicher Sol Projects are going crazy lately📈...
# 4  d3protocol ⚽️ BETERO ⚽️\n\n📲 New platform for ...

# %% [markdown]
# ### Tokeninzing our text by using the split method

# %%
def tokenize(text):
    text = re.split('\s+' ,text)
    return [x.lower() for x in text]

# %%
data['tokens'] = data['removed_punc'].apply(lambda msg : tokenize(msg))
data.head()
# Out:
#                                                 text  \
# 0  RT @Printer_Gobrrr: #LightningNetwork #Bitcoin...
# 1  RT @Blockworks_: 🚨 Meta has filed trademarks a...
# 2  RT @Steampad: 🔥 Unveiling our most Powerful Ch...
# 3  @kseni_cher Sol Projects are going crazy latel...
# 4  @d3protocol ⚽️ BETERO ⚽️\n\n📲 New platform for...
#
#                                         removed_punc  \
# 0  RT PrinterGobrrr LightningNetwork Bitcoin tran...
# 1  RT Blockworks 🚨 Meta has filed trademarks appl...
# 2  RT Steampad 🔥 Unveiling our most Powerful Char...
# 3  ksenicher Sol Projects are going crazy lately📈...
# 4  d3protocol ⚽️ BETERO ⚽️\n\n📲 New platform for ...
#
#                                               tokens
# 0  [rt, printergobrrr, lightningnetwork, bitcoin,...
# 1  [rt, blockworks, 🚨, meta, has, filed, trademar...
# 2  [rt, steampad, 🔥, unveiling, our, most, powerf...
# 3  [ksenicher, sol, projects, are, going, crazy, ...
# 4  [d3protocol, ⚽️, betero, ⚽️, 📲, new, platform,...

# %% [markdown]
# ### This method is for removing all the small words

# %%
def remove_small_words(text):
    return [x for x in text if len(x) > 3 ]

# %%
data['larger_tokens'] = data['tokens'].apply(lambda x : remove_small_words(x))
data.head()
# Out:
#                                                 text  \
# 0  RT @Printer_Gobrrr: #LightningNetwork #Bitcoin...
# 1  RT @Blockworks_: 🚨 Meta has filed trademarks a...
# 2  RT @Steampad: 🔥 Unveiling our most Powerful Ch...
# 3  @kseni_cher Sol Projects are going crazy latel...
# 4  @d3protocol ⚽️ BETERO ⚽️\n\n📲 New platform for...
#
#                                         removed_punc  \
# 0  RT PrinterGobrrr LightningNetwork Bitcoin tran...
# 1  RT Blockworks 🚨 Meta has filed trademarks appl...
# 2  RT Steampad 🔥 Unveiling our most Powerful Char...
# 3  ksenicher Sol Projects are going crazy lately📈...
# 4  d3protocol ⚽️ BETERO ⚽️\n\n📲 New platform for ...
#
#                                               tokens  \
# 0  [rt, printergobrrr, lightningnetwork, bitcoin,...
# 1  [rt, blockworks, 🚨, meta, has, filed, trademar...
# 2  [rt, steampad, 🔥, unveiling, our, most, powerf...
# 3  [ksenicher, sol, projects, are, going, crazy, ...
# 4  [d3protocol, ⚽️, betero, ⚽️, 📲, new, platform,...
#
#                                        larger_tokens
# 0  [printergobrrr, lightningnetwork, bitcoin, tra...
# 1  [blockworks, meta, filed, trademarks, applicat...
# 2  [steampad, unveiling, most, powerful, characte...
# 3  [ksenicher, projects, going, crazy, lately📈, b...
# 4  [d3protocol, betero, platform, easy, crypto, s...

# %% [markdown]
# ### One of they key methods required for this task - 'Removing stop words'

# %%
def remove_stopwords(text):
    return [word for word in text if word not in nltk.corpus.stopwords.words('english')]

# %%
data['stop_words'] = data['larger_tokens'].apply(lambda x : remove_stopwords(x))
data.head()
# Out:
#                                                 text  \
# 0  RT @Printer_Gobrrr: #LightningNetwork #Bitcoin...
# 1  RT @Blockworks_: 🚨 Meta has filed trademarks a...
# 2  RT @Steampad: 🔥 Unveiling our most Powerful Ch...
# 3  @kseni_cher Sol Projects are going crazy latel...
# 4  @d3protocol ⚽️ BETERO ⚽️\n\n📲 New platform for...
#
#                                         removed_punc  \
# 0  RT PrinterGobrrr LightningNetwork Bitcoin tran...
# 1  RT Blockworks 🚨 Meta has filed trademarks appl...
# 2  RT Steampad 🔥 Unveiling our most Powerful Char...
# 3  ksenicher Sol Projects are going crazy lately📈...
# 4  d3protocol ⚽️ BETERO ⚽️\n\n📲 New platform for ...
#
#                                               tokens  \
# 0  [rt, printergobrrr, lightningnetwork, bitcoin,...
# 1  [rt, blockworks, 🚨, meta, has, filed, trademar...
# 2  [rt, steampad, 🔥, unveiling, our, most, powerf...
# 3  [ksenicher, sol, projects, are, going, crazy, ...
# 4  [d3protocol, ⚽️, betero, ⚽️, 📲, new, platform,...
#
#                                        larger_tokens  \
# 0  [printergobrrr, lightningnetwork, bitcoin, tra...
# 1  [blockworks, meta, filed, trademarks, applicat...
# 2  [steampad, unveiling, most, powerful, characte...
# 3  [ksenicher, projects, going, crazy, lately📈, b...
# 4  [d3protocol, betero, platform, easy, crypto, s...
#
#                                         clean_tokens  \
# 0  [printergobrrr, lightningnetwork, bitcoin, tra...
# 1  [blockworks, meta, filed, trademarks, applicat...
# 2  [steampad, unveiling, powerful, characters, ga...
# 3  [ksenicher, projects, going, crazy, lately📈, b...
# 4  [d3protocol, betero, platform, easy, crypto, s...
#
#                                           stop_words
# 0  [printergobrrr, lightningnetwork, bitcoin, tra...
# 1  [blockworks, meta, filed, trademarks, applicat...
# 2  [steampad, unveiling, powerful, characters, ga...
# 3  [ksenicher, projects, going, crazy, lately📈, b...
# 4  [d3protocol, betero, platform, easy, crypto, s...

# %% [markdown]
# ### Performing stemming using the 'PorterStemmer' function

# %%
def stemming(text):
    ps = PorterStemmer()
    return [ps.stem(word) for word in text]

# %%
data['stemming_words'] = data['clean_tokens'].apply(lambda wrd: stemming(wrd))
data.head()
# Out:
#                                                 text  \
# 0  RT @Printer_Gobrrr: #LightningNetwork #Bitcoin...
# 1  RT @Blockworks_: 🚨 Meta has filed trademarks a...
# 2  RT @Steampad: 🔥 Unveiling our most Powerful Ch...
# 3  @kseni_cher Sol Projects are going crazy latel...
# 4  @d3protocol ⚽️ BETERO ⚽️\n\n📲 New platform for...
#
#                                         removed_punc  \
# 0  RT PrinterGobrrr LightningNetwork Bitcoin tran...
# 1  RT Blockworks 🚨 Meta has filed trademarks appl...
# 2  RT Steampad 🔥 Unveiling our most Powerful Char...
# 3  ksenicher Sol Projects are going crazy lately📈...
# 4  d3protocol ⚽️ BETERO ⚽️\n\n📲 New platform for ...
#
#                                               tokens  \
# 0  [rt, printergobrrr, lightningnetwork, bitcoin,...
# 1  [rt, blockworks, 🚨, meta, has, filed, trademar...
# 2  [rt, steampad, 🔥, unveiling, our, most, powerf...
# 3  [ksenicher, sol, projects, are, going, crazy, ...
# 4  [d3protocol, ⚽️, betero, ⚽️, 📲, new, platform,...
#
#                                        larger_tokens  \
# 0  [printergobrrr, lightningnetwork, bitcoin, tra...
# 1  [blockworks, meta, filed, trademarks, applicat...
# 2  [steampad, unveiling, most, powerful, characte...
# 3  [ksenicher, projects, going, crazy, lately📈, b...
# 4  [d3protocol, betero, platform, easy, crypto, s...
#
#                                         clean_tokens  \
# 0  [printergobrrr, lightningnetwork, bitcoin, tra...
# 1  [blockworks, meta, filed, trademarks, applicat...
# 2  [steampad, unveiling, powerful, characters, ga...
# 3  [ksenicher, projects, going, crazy, lately📈, b...
# 4  [d3protocol, betero, platform, easy, crypto, s...
#
#                                           stop_words  \
# 0  [printergobrrr, lightningnetwork, bitcoin, tra...
# 1  [blockworks, meta, filed, trademarks, applicat...
# 2  [steampad, unveiling, powerful, characters, ga...
# 3  [ksenicher, projects, going, crazy, lately📈, b...
# 4  [d3protocol, betero, platform, easy, crypto, s...
#
#                                       stemming_words
# 0  [printergobrrr, lightningnetwork, bitcoin, tra...
# 1  [blockwork, meta, file, trademark, applic, log...
# 2  [steampad, unveil, power, charact, game, launc...
# 3  [ksenich, project, go, crazi, lately📈, battlef...
# 4  [d3protocol, betero, platform, easi, crypto, s...

# %% [markdown]
# ### Performing Lemmatization using the 'WordNetLemmatizer' function

# %%
def lemmatize(text):
    word_net = WordNetLemmatizer()
    return [word_net.lemmatize(word) for word in text]

# %%
data['lemmatization_words'] = data['clean_tokens'].apply(lambda x : lemmatize(x))
data.head()
# Out:
#                                                 text  \
# 0  RT @Printer_Gobrrr: #LightningNetwork #Bitcoin...
# 1  RT @Blockworks_: 🚨 Meta has filed trademarks a...
# 2  RT @Steampad: 🔥 Unveiling our most Powerful Ch...
# 3  @kseni_cher Sol Projects are going crazy latel...
# 4  @d3protocol ⚽️ BETERO ⚽️\n\n📲 New platform for...
#
#                                         removed_punc  \
# 0  RT PrinterGobrrr LightningNetwork Bitcoin tran...
# 1  RT Blockworks 🚨 Meta has filed trademarks appl...
# 2  RT Steampad 🔥 Unveiling our most Powerful Char...
# 3  ksenicher Sol Projects are going crazy lately📈...
# 4  d3protocol ⚽️ BETERO ⚽️\n\n📲 New platform for ...
#
#                                               tokens  \
# 0  [rt, printergobrrr, lightningnetwork, bitcoin,...
# 1  [rt, blockworks, 🚨, meta, has, filed, trademar...
# 2  [rt, steampad, 🔥, unveiling, our, most, powerf...
# 3  [ksenicher, sol, projects, are, going, crazy, ...
# 4  [d3protocol, ⚽️, betero, ⚽️, 📲, new, platform,...
#
#                                        larger_tokens  \
# 0  [printergobrrr, lightningnetwork, bitcoin, tra...
# 1  [blockworks, meta, filed, trademarks, applicat...
# 2  [steampad, unveiling, most, powerful, characte...
# 3  [ksenicher, projects, going, crazy, lately📈, b...
# 4  [d3protocol, betero, platform, easy, crypto, s...
#
#                                         clean_tokens  \
# 0  [printergobrrr, lightningnetwork, bitcoin, tra...
# 1  [blockworks, meta, filed, trademarks, applicat...
# 2  [steampad, unveiling, powerful, characters, ga...
# 3  [ksenicher, projects, going, crazy, lately📈, b...
# 4  [d3protocol, betero, platform, easy, crypto, s...
#
#                                           stop_words  \
# 0  [printergobrrr, lightningnetwork, bitcoin, tra...
# 1  [blockworks, meta, filed, trademarks, applicat...
# 2  [steampad, unveiling, powerful, characters, ga...
# 3  [ksenicher, projects, going, crazy, lately📈, b...
# 4  [d3protocol, betero, platform, easy, crypto, s...
#
#                                       stemming_words  \
# 0  [printergobrrr, lightningnetwork, bitcoin, tra...
# 1  [blockwork, meta, file, trademark, applic, log...
# 2  [steampad, unveil, power, charact, game, launc...
# 3  [ksenich, project, go, crazi, lately📈, battlef...
# 4  [d3protocol, betero, platform, easi, crypto, s...
#
#                                  lemmatization_words
# 0  [printergobrrr, lightningnetwork, bitcoin, tra...
# 1  [blockworks, meta, filed, trademark, applicati...
# 2  [steampad, unveiling, powerful, character, gam...
# 3  [ksenicher, project, going, crazy, lately📈, ba...
# 4  [d3protocol, betero, platform, easy, crypto, s...

# %% [markdown]
# ### These next few codes are for extracting 'cleaner text'

# %%
def return_sentences(tokens):
    return " ".join([word for word in tokens])

# %%
data['clean_text'] = data['lemmatization_words'].apply(lambda x : return_sentences(x))
data.head()
# Out:
#                                                 text  \
# 0  RT @Printer_Gobrrr: #LightningNetwork #Bitcoin...
# 1  RT @Blockworks_: 🚨 Meta has filed trademarks a...
# 2  RT @Steampad: 🔥 Unveiling our most Powerful Ch...
# 3  @kseni_cher Sol Projects are going crazy latel...
# 4  @d3protocol ⚽️ BETERO ⚽️\n\n📲 New platform for...
#
#                                         removed_punc  \
# 0  RT PrinterGobrrr LightningNetwork Bitcoin tran...
# 1  RT Blockworks 🚨 Meta has filed trademarks appl...
# 2  RT Steampad 🔥 Unveiling our most Powerful Char...
# 3  ksenicher Sol Projects are going crazy lately📈...
# 4  d3protocol ⚽️ BETERO ⚽️\n\n📲 New platform for ...
#
#                                               tokens  \
# 0  [rt, printergobrrr, lightningnetwork, bitcoin,...
# 1  [rt, blockworks, 🚨, meta, has, filed, trademar...
# 2  [rt, steampad, 🔥, unveiling, our, most, powerf...
# 3  [ksenicher, sol, projects, are, going, crazy, ...
# 4  [d3protocol, ⚽️, betero, ⚽️, 📲, new, platform,...
#
#                                        larger_tokens  \
# 0  [printergobrrr, lightningnetwork, bitcoin, tra...
# 1  [blockworks, meta, filed, trademarks, applicat...
# 2  [steampad, unveiling, most, powerful, characte...
# 3  [ksenicher, projects, going, crazy, lately📈, b...
# 4  [d3protocol, betero, platform, easy, crypto, s...
#
#                                         clean_tokens  \
# 0  [printergobrrr, lightningnetwork, bitcoin, tra...
# 1  [blockworks, meta, filed, trademarks, applicat...
# 2  [steampad, unveiling, powerful, characters, ga...
# 3  [ksenicher, projects, going, crazy, lately📈, b...
# 4  [d3protocol, betero, platform, easy, crypto, s...
#
#                                           stop_words  \
# 0  [printergobrrr, lightningnetwork, bitcoin, tra...
# 1  [blockworks, meta, filed, trademarks, applicat...
# 2  [steampad, unveiling, powerful, characters, ga...
# 3  [ksenicher, projects, going, crazy, lately📈, b...
# 4  [d3protocol, betero, platform, easy, crypto, s...
#
#                                       stemming_words  \
# 0  [printergobrrr, lightningnetwork, bitcoin, tra...
# 1  [blockwork, meta, file, trademark, applic, log...
# 2  [steampad, unveil, power, charact, game, launc...
# 3  [ksenich, project, go, crazi, lately📈, battlef...
# 4  [d3protocol, betero, platform, easi, crypto, s...
#
#                                  lemmatization_words  \
# 0  [printergobrrr, lightningnetwork, bitcoin, tra...
# 1  [blockworks, meta, filed, trademark, applicati...
# 2  [steampad, unveiling, powerful, character, gam...
# 3  [ksenicher, project, going, crazy, lately📈, ba...
# 4  [d3protocol, betero, platform, easy, crypto, s...
#
#                                           clean_text
# 0  printergobrrr lightningnetwork bitcoin transac...
# 1  blockworks meta filed trademark application lo...
# 2  steampad unveiling powerful character game lau...
# 3  ksenicher project going crazy lately📈 battlefo...
# 4  d3protocol betero platform easy crypto sport b...

# %% [markdown]
# ### Assigning 'r' to the 'clean_text' variable

# %%
r = ['clean_text']

# %% [markdown]
# ### Collecting all the 'cleaned text' to a csv file

# %%
for r in words: 
    if not r in stop_words: 
        appendFile = open('text_processing.csv','a', encoding='utf-8') 
        appendFile.write(r)
        appendFile.write("\n")
        appendFile.close()

# %% [markdown]
# ## Finding the top 10 most frequent topic words in the text

# %%
data = pd.read_csv("text_processing.csv") 
from collections import Counter
Counter(" ".join(data["text"]).split()).most_common(10)
# Out:
# [('RT', 4202),
#  ('crypto', 751),
#  ('&amp;', 671),
#  ('Crypto', 492),
#  ('I', 465),
#  ('#Bitcoin', 447),
#  ('-', 446),
#  ('#Crypto', 431),
#  ('project', 402),
#  ('The', 396)]
